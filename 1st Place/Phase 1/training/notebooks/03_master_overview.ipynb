# %%
import os
import numpy as np
import pandas as pd
from tqdm import tqdm
from catboost import CatBoostRegressor

# %% [markdown]
# ### Master table overview

# %%
master = pd.read_parquet('../data/05_model_input/master_katl.pq')
print(master.shape)
master.head()
# Out:
# (3627357, 297)
#                                         gufi           timestamp  \
# 0  AAL1008.ATL.DFW.210403.1312.0051.TFM_TFDM 2021-04-03 19:30:00
# 1  AAL1008.ATL.DFW.210403.1312.0051.TFM_TFDM 2021-04-03 19:45:00
# 2  AAL1008.ATL.DFW.210403.1312.0051.TFM_TFDM 2021-04-03 20:00:00
# 3  AAL1008.ATL.DFW.210403.1312.0051.TFM_TFDM 2021-04-03 20:15:00
# 4  AAL1008.ATL.DFW.210403.1312.0051.TFM_TFDM 2021-04-03 20:30:00
#
#    minutes_until_pushback mfs_cat_flightid mfs_cat_flightno  \
# 0                     114          AAL1008             1008
# 1                      99          AAL1008             1008
# 2                      84          AAL1008             1008
# 3                      69          AAL1008             1008
# 4                      54          AAL1008             1008
#
#    mfs_flightno_length mfs_cat_no_last mfs_cat_arrival  mfs_cat_hourdep  \
# 0                    4               8             DFW               13
# ...

# %%
master.dtypes.value_counts()
# Out:
# int16             286
# object              9
# datetime64[ns]      1
# int64               1
# dtype: int64
