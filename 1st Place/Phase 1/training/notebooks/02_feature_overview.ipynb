# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
from tqdm import tqdm
# Out:
# [02/21/23 11:24:48] WARNING  /home/alsaco/anaconda3/lib/python3.9/site-packages/matplotlib/__init__ ]8;id=67537;file:///home/alsaco/anaconda3/lib/python3.9/warnings.py\warnings.py]8;;\:]8;id=544874;file:///home/alsaco/anaconda3/lib/python3.9/warnings.py#109\109]8;;\
#                              .py:152: DeprecationWarning: distutils Version classes are deprecated.
#                              Use packaging.version instead.
#                                if LooseVersion(module.__version__) < minver:
#                     WARNING  /home/alsaco/anaconda3/lib/python3.9/site-packages/setuptools/_distuti ]8;id=135357;file:///home/alsaco/anaconda3/lib/python3.9/warnings.py\warnings.py]8;;\:]8;id=880339;file:///home/alsaco/anaconda3/lib/python3.9/warnings.py#109\109]8;;\
#                              ls/version.py:345: DeprecationWarning: distutils Version classes are
#                              deprecated. Use packaging.version instead.
# ...

# %%
# %reload_kedro
# Out:
# [02/21/23 11:24:54] INFO     Resolved project path as: /home/alsaco/Desktop/pushack-nasa/training.  ]8;id=903813;file:///home/alsaco/anaconda3/lib/python3.9/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=396740;file:///home/alsaco/anaconda3/lib/python3.9/site-packages/kedro/ipython/__init__.py#134\134]8;;\
#                              To set a different path, run '%reload_kedro <project_root>'
#                     WARNING  /home/alsaco/anaconda3/lib/python3.9/site-packages/kedro/framework/sta ]8;id=586861;file:///home/alsaco/anaconda3/lib/python3.9/warnings.py\warnings.py]8;;\:]8;id=419918;file:///home/alsaco/anaconda3/lib/python3.9/warnings.py#109\109]8;;\
#                              rtup.py:98: DeprecationWarning: project_version in pyproject.toml is
#                              deprecated, use kedro_init_version instead
#                                warnings.warn(
# ...

# %% [markdown]
# ### 1. Airport configuration

# %%
config = catalog.load('features_katl_config')
print(config.shape)
config.head()
# Out:
# [02/21/23 11:25:04] INFO     Loading data from 'features_katl_config' (ParquetDataSet)...       ]8;id=46524;file:///home/alsaco/anaconda3/lib/python3.9/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=954608;file:///home/alsaco/anaconda3/lib/python3.9/site-packages/kedro/io/data_catalog.py#343\343]8;;\
# (219169, 55)
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>timestamp</th>
#       <th>config_arrival_cat_9</th>
#       <th>config_departure_cat_9</th>
#       <th>config_arrival_cat_17</th>
#       <th>config_departure_cat_17</th>
#       <th>config_arrival_cat_34</th>
#       <th>config_departure_cat_34</th>
# ...

# %% [markdown]
# ### 2. Estimated departure times (ETD)

# %%
etd = catalog.load('features_katl_etd')
print(etd.shape)
etd.head()
# Out:
# [02/21/23 11:25:14] INFO     Loading data from 'features_katl_etd' (ParquetDataSet)...          ]8;id=456420;file:///home/alsaco/anaconda3/lib/python3.9/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=229786;file:///home/alsaco/anaconda3/lib/python3.9/site-packages/kedro/io/data_catalog.py#343\343]8;;\
# (9199355, 55)
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>gufi</th>
#       <th>timestamp</th>
#       <th>etd_est_change</th>
#       <th>etd_diff_withfirst</th>
#       <th>etd_time_till_est_dep</th>
#       <th>etd_roll_30_count</th>
#       <th>etd_roll_60_count</th>
#       <th>etd_roll_90_count</th>
# ...

# %% [markdown]
# ### 4. Weather (lamp)

# %%
lamp = catalog.load('features_katl_lamp')
print(lamp.shape)
lamp.head()
# Out:
# [02/21/23 11:25:46] INFO     Loading data from 'features_katl_lamp' (ParquetDataSet)...         ]8;id=852019;file:///home/alsaco/anaconda3/lib/python3.9/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=207420;file:///home/alsaco/anaconda3/lib/python3.9/site-packages/kedro/io/data_catalog.py#343\343]8;;\
# (73057, 163)
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>timestamp</th>
#       <th>temp_temperature_mean_last6h</th>
#       <th>temp_temperature_min_last6h</th>
#       <th>temp_temperature_max_last6h</th>
#       <th>temp_wind_direction_mean_last6h</th>
#       <th>temp_wind_direction_min_last6h</th>
# ...

# %% [markdown]
# ### 5. MFS

# %%
mfs = catalog.load('features_katl_mfs')
print(mfs.shape)
mfs.head()
# Out:
# [02/21/23 11:26:00] INFO     Loading data from 'features_katl_mfs' (ParquetDataSet)...          ]8;id=651879;file:///home/alsaco/anaconda3/lib/python3.9/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=224633;file:///home/alsaco/anaconda3/lib/python3.9/site-packages/kedro/io/data_catalog.py#343\343]8;;\
# (3497868, 14)
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>gufi</th>
#       <th>timestamp</th>
#       <th>mfs_cat_flightid</th>
#       <th>mfs_cat_flightno</th>
#       <th>mfs_flightno_length</th>
#       <th>mfs_cat_no_last</th>
#       <th>mfs_cat_arrival</th>
#       <th>mfs_cat_hourdep</th>
#       <th>mfs_time_diff</th>
# ...

# %% [markdown]
# ### 6. Runways

# %%
runways = catalog.load('features_katl_runways')
print(runways.shape)
runways.head()
# Out:
# [02/21/23 11:26:07] INFO     Loading data from 'features_katl_runways' (ParquetDataSet)...      ]8;id=395948;file:///home/alsaco/anaconda3/lib/python3.9/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=93041;file:///home/alsaco/anaconda3/lib/python3.9/site-packages/kedro/io/data_catalog.py#343\343]8;;\
# (73057, 17)
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>timestamp</th>
#       <th>runways_15_totdep</th>
#       <th>runways_30_totdep</th>
#       <th>runways_60_totdep</th>
#       <th>runways_90_totdep</th>
#       <th>runways_120_totdep</th>
#       <th>runways_360_totdep</th>
#       <th>runways_720_totdep</th>
# ...

# %% [markdown]
# ### 7. TBFM (time-based flow management)

# %%
tbfm = catalog.load('features_katl_tbfm')
print(tbfm.shape)
tbfm.head()
# Out:
# [02/21/23 11:26:17] INFO     Loading data from 'features_katl_tbfm' (ParquetDataSet)...         ]8;id=804547;file:///home/alsaco/anaconda3/lib/python3.9/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=967690;file:///home/alsaco/anaconda3/lib/python3.9/site-packages/kedro/io/data_catalog.py#343\343]8;;\
# (73055, 25)
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>timestamp</th>
#       <th>tbfm_delay_30_count</th>
#       <th>tbfm_delay_60_count</th>
#       <th>tbfm_delay_90_count</th>
#       <th>tbfm_delay_120_count</th>
#       <th>tbfm_delay_240_count</th>
#       <th>tbfm_delay_360_count</th>
#       <th>tbfm_delay_720_count</th>
# ...

# %% [markdown]
# ### 8. TFM (traffic flow management)

# %%
tfm = catalog.load('features_katl_tfm')
print(tfm.shape)
tfm.head()
# Out:
# [02/21/23 11:26:23] INFO     Loading data from 'features_katl_tfm' (ParquetDataSet)...          ]8;id=357008;file:///home/alsaco/anaconda3/lib/python3.9/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=430775;file:///home/alsaco/anaconda3/lib/python3.9/site-packages/kedro/io/data_catalog.py#343\343]8;;\
# (73055, 25)
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>timestamp</th>
#       <th>tfm_delay_30_count</th>
#       <th>tfm_delay_60_count</th>
#       <th>tfm_delay_90_count</th>
#       <th>tfm_delay_120_count</th>
#       <th>tfm_delay_240_count</th>
#       <th>tfm_delay_360_count</th>
#       <th>tfm_delay_720_count</th>
# ...
